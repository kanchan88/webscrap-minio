# %% [markdown]
# #### Listing URLS selling Laptop

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd
from requests_html import HTMLSession
import csv

# %%
all_links = urls.copy()

# %%
responses = []

for link in all_links:
    response = requests.request("GET", f"http://api.scraperapi.com?api_key=ae939ef3d321a5638cef3e2178304155&url={link}")
    responses.append(response.text)

# %%
print(responses[0])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Dell P2719H 27 inch Full HD Monitor Price in India, Specs, Reviews, Offers, Coupons | Topprice.in</title>
# <meta charset="UTF-8" />
# <base href="https://www.topprice.in/" />
# <meta name="format-detection" content="telephone=no" />
# <link rel="preconnect dns-prefetch" href="//i.ytimg.com">
# <link rel="preconnect dns-prefetch" href="https://www.googletagmanager.com" crossorigin>
# <link rel="preconnect dns-prefetch" href="https://www.google-analytics.com" crossorigin>
# <meta name="viewport" content="width=device-width, initial-scale=1"> <meta name="description" content="Price starts from ₹18,399. ✔️ Lowest Price ✔️ FREE Shipping ✔️ COD. Dell P2719H 27 inch Full HD Monitor Colours:" /><meta name="keywords" content="Dell,P2719H,27,inch,Full,HD,Monitor" /><!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><![endif]-->
# <link href="/catalog/view/javascript/font-awesome/fonts/fontawesome-webfont.woff2?v=4.7.0" rel="preload" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="cache/minify/e447add3c8625e763b31c9c737aa1755.css?v=2.6" as="style">
# <link rel="stylesheet" href="cache/minify/e447add3c8625e763b31c9c737aa1755.css?v=2.6">
# <link rel="preload" href="cache/minify/f6ece1b573fa787d34287d2ec6fe50d7.js?v=2.6" as="script">
# <script src="cache/minify/f6ece1b573fa787d34287d2ec6fe50d7.js?v=2.6" type="88b0ad11c0af5c1b2c69bc85-text/javascript"></script>
# <style>body{font-family:inherit}	</style>
# <style>.ct-font{font-family:inherit}	</style>
# <style>
# 	body {
# 			background-color:#f5f5f5;
# 			}
# 	</style>
# <link href="https://www.topprice.in/dell-p2719h-27-inch-full-hd-monitor-p134834" rel="canonical" />
# <link href="https://www.topprice.in/image/catalog/cart.png" rel="icon" />
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-107019716-1" type="88b0ad11c0af5c1b2c69bc85-text/javascript"></script>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-107019716-1');
# </script><script type="application/ld+json">{"@context": "https://schema.org","@type": "WebSite","url": "https://www.topprice.in/","potentialAction": {
#         "@type": "SearchAction","target": "https://www.topprice.in/index.php?route=product/search&search={search_term_string}","query-input": "required name=search_term_string"}}
# </script>
#
# <meta property="og:title" content="Dell P2719H 27 inch Full HD Monitor Price in India, Specs, Reviews, Offers, Coupons | Topprice.in">
# <meta property="og:description" content="Price starts from ₹18,399. ✔️ Lowest Price ✔️ FREE Shipping ✔️ COD. Dell P2719H 27 inch Full HD Monitor Colours:">
# <meta property="og:site_name" content="Topprice.in">
# <meta property="og:url" content="https://www.topprice.in/dell-p2719h-27-inch-full-hd-monitor-p134834">
# <meta property="og:image" content="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-600x600.jpg">
# <meta property="og:image:secure_url" content="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-600x600.jpg">
# <meta property="og:image:width" content="600">
# <meta property="og:image:height" content="600">
# <meta property="og:image:type" content="image/jpg">
# <meta property="product:price:amount" content="18399.00">
# <meta property="product:price:currency" content="INR">
# <meta property="og:type" content="website">
#
# </head>
# <body class="product-product-134834 ltr res layout-1  ">
# <div id="wrapper" class="wrapper-full banners-effect-6">
# <header id="header" class=" variant typeheader-1">
#
# <div class="header-top">
# <div class="container">
# <div class="row">
# <div class="col-lg-3 col-xs-6 header-logo ">
# <div class="navbar-logo">
# <a href="https://www.topprice.in/"><img src="https://www.topprice.in/image/catalog/Store_Logos/Topprice_logo.png" title="Topprice.in" alt="Topprice.in" /></a>
# </div>
# </div>
# <div class="col-lg-5 header-sevices">
# <div class="module html--sevices">
# <div class="clearfix">
# <ul>
# <li class="col-md-4 item ">
# <div><div class="col-md-2 item " style="background-image: url(../image/catalog/Store_Logos/Find.png);background-position:center;
#   background-repeat:no-repeat; background-size: 60px 60px; height: 60px; width: 60px;"> </div><div style="padding-top: 20px;">Find Products</div></div>
# </li>
# <li class="col-md-4 item ">
# <div><div class="col-md-2 item " style="background-image: url(../image/catalog/Store_Logos/Compare.png);background-position:center;
#   background-repeat:no-repeat; background-size: 60px 60px; height: 60px; width: 60px;"> </div> <div style="padding-top: 20px;">Compare Price</div></div>
# </li>
# <li class="col-md-4 item ">
# <div><div class="col-md-2 item " style="background-image: url(../image/catalog/Store_Logos/Shop.png);background-position:center;
#   background-repeat:no-repeat; background-size: 60px 60px; height: 60px; width: 60px;"> </div> <div style="padding-top: 20px;">Buy Online </div></div>
# </li>
# </ul></div></div> </div>
#
# <div class="col-lg-2 header-cart">
# <div class="header-sevices megamenucust1">
#
# <ul class="megamenu megamenucust" data-transition="slide" data-animationtime="300">
# <li class="style-page with-sub-menu hover"><p class="close-menu"></p><a href="https://www.topprice.in/index.php?route=account/account" class="dropdown-toggle" data-toggle="dropdown" aria-expanded="false"><i class="fa fa-user"></i> <span class="hidden-xs hidden-sm">My Account</span> <span class="caret"></span></a>
# <div class="sub-menu" style="width: 230px; display: block; right: 0px;"><div class="content" style="display: block; height: 128px;"><div class="row"><div class="col-sm-12"><div class="html "><ul id="myaccount" class="row-list" style="font-size: 14px;">
# <li><a class="subcategory_item" href="https://www.topprice.in/index.php?route=account/login">Login</a></li>
# <li><a class="subcategory_item" href="https://www.topprice.in/index.php?route=account/register">Register</a></li>
# </ul></div></div></div></div></div>
# </li>
# </ul>
# </div>
# <div class="shopping_cart">
# </div>
# </div>
# </div>
# </div>
# </div>
#
# <div class="header-center">
# <div class="container">
# <div class="row">
# <div class="col-lg-6 col-md-6 col-sm-1 col-xs-3 header-menu">
# <div class="responsive megamenu-style-dev megamenu-dev">
# <nav class="navbar-default">
# <div class=" container-megamenu  horizontal">
# <div class="navbar-header">
# <button type="button" id="show-megamenu" data-toggle="collapse" class="navbar-toggle">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="megamenu-wrapper">
# <span id="remove-megamenu" class="fa fa-times"></span>
# <div class="megamenu-pattern">
# <div class="container">
# <ul class="megamenu" data-transition="slide" data-animationtime="300">
# <li class='home'><p class='close-menu'></p><a href='/' class='clearfix'>
# <strong>
# Home
# </strong>
#
# </a></li>
# <li class=''><p class='close-menu'></p><a href='/specials' class='clearfix'>
# <strong>
# Today's Deals
# </strong>
# </a></li>
# <li class=''><p class='close-menu'></p><a href='/reviews' class='clearfix' target="_blank">
# <strong>
# Product Reviews
# </strong>
# </a></li>
# <li class=''><p class='close-menu'></p><a href='/index.php?route=product/compare' class='clearfix'>
# <strong>
# Compare
# </strong>
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="col-lg-6 col-md-4 col-sm-11 col-xs-9 header-search">
# <div id="sosearchpro" class="sosearchpro-wrapper so-search search-pro so-search">
# <form method="GET" action="index.php">
# <div id="search0" class="search input-group">
# <div class="select_category filter_type  icon-select">
# <select class="no-border" name="category_id">
# <option value="0">All Categories</option>
# <option value="174">Automobile</option>
# <option value="175">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Accessories</option>
# <option value="176">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Chargers</option>
# <option value="178">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Cradles &amp; Mounts</option>
# <option value="177">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Kits</option>
# <option value="281">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Speakers</option>
# <option value="270">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Car Stereos</option>
# <option value="179">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;GPS Navigation Devices</option>
# <option value="238">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Motorbike Accessories</option>
# <option value="239">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Helmets</option>
# <option value="88">Baby &amp; Toys</option>
# <option value="253">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Diapers</option>
# <option value="254">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Disposable Diapers</option>
# <option value="89">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Toys &amp; Games</option>
# <option value="91">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Building &amp; Construction Toys</option>
# <option value="215">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Remote Control Toys</option>
# <option value="90">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Soft Toys</option>
# <option value="100">Beauty</option>
# <option value="319">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Eye</option>
# <option value="320">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Eye Shadow</option>
# <option value="321">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kajal</option>
# <option value="322">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mascara</option>
# <option value="101">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Face</option>
# <option value="103">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Compact Powder</option>
# <option value="102">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Foundation</option>
# <option value="104">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Fragrance</option>
# <option value="105">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Men's Deodorants</option>
# <option value="272">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Men's Perfumes</option>
# <option value="106">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Women's Deodorants</option>
# <option value="273">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Women's Perfumes</option>
# <option value="314">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lips</option>
# <option value="318">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lip Balms </option>
# <option value="317">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lip Gloss</option>
# <option value="316">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lip Liners</option>
# <option value="315">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lipstick</option>
# <option value="261">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Men Shaving &amp; Grooming</option>
# <option value="266">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;After Shaves</option>
# <option value="262">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cartridges &amp; Blades</option>
# <option value="265">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Razors</option>
# <option value="267">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Shaving Foam, Cream &amp; Gels</option>
# <option value="310">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nail</option>
# <option value="313">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nail Effects</option>
# <option value="311">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nail Polish</option>
# <option value="312">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nail Polish Remover</option>
# <option value="249">Books, Office &amp; Stationery</option>
# <option value="68">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Books</option>
# <option value="69">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;School Textbooks &amp; Guides</option>
# <option value="250">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Calculators</option>
# <option value="282">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Note Counting Machines</option>
# <option value="251">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Security Systems</option>
# <option value="291">Care</option>
# <option value="161">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Health Care Devices</option>
# <option value="169">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Body Fat Analyzer</option>
# <option value="162">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;BP Monitor</option>
# <option value="163">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Digital Thermometer</option>
# <option value="168">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Glucometer</option>
# <option value="167">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Heating Pad</option>
# <option value="165">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Massager</option>
# <option value="164">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Nebulizer</option>
# <option value="170">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pedometer</option>
# <option value="166">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pulse Oximeter</option>
# <option value="214">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Weighing Scales</option>
# <option value="230">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Personal Care Devices</option>
# <option value="236">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Electric Toothbrush</option>
# <option value="232">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Epilator</option>
# <option value="235">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hair Curlers</option>
# <option value="233">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hair Dryers</option>
# <option value="234">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hair Straighteners</option>
# <option value="237">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hair Stylers</option>
# <option value="231">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Trimmers</option>
# <option value="308">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vision Care</option>
# <option value="292">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pet Care</option>
# <option value="293">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pet food</option>
# <option value="257">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Weight Loss Products</option>
# <option value="70">Fashion</option>
# <option value="71">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Men's Fashion</option>
# <option value="72">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Men's Clothing</option>
# <option value="75">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sunglasses for men</option>
# <option value="74">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Women's Fashion</option>
# <option value="95">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Handbags &amp; Clutches</option>
# <option value="73">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Women's Clothing</option>
# <option value="82">Home &amp; Kitchen</option>
# <option value="83">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cooking Essentials</option>
# <option value="85">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Frying Pans</option>
# <option value="84">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Gas Stoves</option>
# <option value="86">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pressure Cookers</option>
# <option value="194">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Roti Makers</option>
# <option value="92">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Home Appliances</option>
# <option value="94">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Air Conditioners</option>
# <option value="264">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Air Purifiers</option>
# <option value="160">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Dishwashers</option>
# <option value="268">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Emergency Lights</option>
# <option value="201">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Heaters, Fans &amp; Coolers</option>
# <option value="280">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Inverters &amp; Batteries</option>
# <option value="200">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Irons</option>
# <option value="93">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Refrigerators</option>
# <option value="307">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Spike Surge Protectors</option>
# <option value="159">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vacuum Cleaners</option>
# <option value="205">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Voltage Stabilizers</option>
# <option value="158">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Washing Machines &amp; Dryers</option>
# <option value="186">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kitchen Appliances</option>
# <option value="197">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Air Fryers</option>
# <option value="271">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Chimneys</option>
# <option value="189">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Choppers &amp; Blenders</option>
# <option value="198">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Coffee Makers</option>
# <option value="190">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Electric (Rice) Cookers</option>
# <option value="187">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Electric Kettles</option>
# <option value="196">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Food Processors</option>
# <option value="188">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Induction Cook Tops</option>
# <option value="192">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Microwave Ovens</option>
# <option value="256">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mixer Grinder</option>
# <option value="191">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pop Up (Bread) Toasters</option>
# <option value="195">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sandwich Makers</option>
# <option value="193">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Water Purifiers</option>
# <option value="255">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;LED Lights</option>
# <option value="279">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Safe Lockers</option>
# <option value="258">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Solar Appliances</option>
# <option value="274">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tools &amp; Hardware</option>
# <option value="276">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hand Tools</option>
# <option value="277">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Measuring Tools</option>
# <option value="275">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Power Tools</option>
# <option value="278">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tool Accessories</option>
# <option value="216">Musical Instruments</option>
# <option value="228">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Drums &amp; Percussions</option>
# <option value="217">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Guitars</option>
# <option value="229">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Indian Instruments </option>
# <option value="218">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pianos &amp; Keyboards</option>
# <option value="77">Software</option>
# <option value="78">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Antivirus &amp; Security Software</option>
# <option value="199">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Microsoft Office</option>
# <option value="79">Sports &amp; Fitness</option>
# <option value="240">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Badminton</option>
# <option value="243">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Grips </option>
# <option value="241">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Racquets </option>
# <option value="242">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Shuttles </option>
# <option value="244">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Strings </option>
# <option value="309">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Camping &amp; Outdoor Adventure</option>
# <option value="81">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket</option>
# <option value="209">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Balls</option>
# <option value="208">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Bats</option>
# <option value="211">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Gloves</option>
# <option value="212">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Helmets</option>
# <option value="213">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Kit Bags</option>
# <option value="210">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cricket Sets</option>
# <option value="171">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cycling</option>
# <option value="172">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Bicycle Accessories</option>
# <option value="173">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Bicycles</option>
# <option value="80">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Exercise &amp; Fitness</option>
# <option value="248">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cross &amp; Elliptical Trainers</option>
# <option value="247">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Home Gym</option>
# <option value="246">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Treadmills</option>
# <option value="96">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Other Sports</option>
# <option value="97">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Billiards</option>
# <option value="98">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Boxing</option>
# <option value="99">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hockey</option>
# <option value="289">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Scooters</option>
# <option value="290">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Skateboards</option>
# <option value="245">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sports Supplements</option>
# <option value="61">Electronics</option>
# <option value="66">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Audio &amp; Video</option>
# <option value="285">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;AV Receivers</option>
# <option value="286">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Boom Boxes</option>
# <option value="287">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FM Radio</option>
# <option value="182">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Gaming Console</option>
# <option value="181">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Home Theaters</option>
# <option value="149">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;LCD &amp; LED TVs</option>
# <option value="67">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;MP3/MP4 Players </option>
# <option value="180">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Projectors</option>
# <option value="288">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Remote Controls</option>
# <option value="283">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Smart TV Boxes</option>
# <option value="284">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sound Amplifiers</option>
# <option value="183">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Video &amp; DVD Players</option>
# <option value="138">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cameras &amp; Accessories</option>
# <option value="139">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cameras &amp; Camcorders</option>
# <option value="185">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Digital Photo Frame</option>
# <option value="148">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Flash &amp; Accessories</option>
# <option value="143">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lenses &amp; Accessories</option>
# <option value="184">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Surveillance Cameras</option>
# <option value="147">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tripods</option>
# <option value="64">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Computers &amp; Accessories</option>
# <option value="76">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Computer Accessories &amp; Peripherals</option>
# <option value="294">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Desktop &amp; Components</option>
# <option value="65">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Laptops</option>
# <option value="63">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Tablets</option>
# <option value="59">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mobiles &amp; Accessories</option>
# <option value="62">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mobile Accessories</option>
# <option value="60">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Mobile Phones</option>
# </select>
# </div>
# <input class="autosearch-input form-control" type="text" value="" size="50" autocomplete="off" placeholder="Enter search..." name="search">
# <span class="input-group-btn">
# <button type="submit" class="button-search btn btn-default btn-lg" name="submit_search"><i class="fa fa-search"></i></button>
# </span>
# </div>
# <input type="hidden" name="route" value="product/search" />
# </form>
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
# // Autocomplete */
# (function($) {
# 	$.fn.Soautocomplete = function(option) {
# 		return this.each(function() {
# 			this.timer = null;
# 			this.items = new Array();
#
# 			$.extend(this, option);
#
# 			$(this).attr('autocomplete', 'off');
#
# 			// Focus
# 			$(this).on('focus', function() {
# 				this.request();
# 			});
#
# 			// Blur
# 			$(this).on('blur', function() {
# 				setTimeout(function(object) {
# 					object.hide();
# 				}, 200, this);
# 			});
#
# 			// Keydown
# 			$(this).on('keydown', function(event) {
# 				switch(event.keyCode) {
# 					case 27: // escape
# 						this.hide();
# 						break;
# 					default:
# 						this.request();
# 						break;
# 				}
# 			});
#
# 			// Click
# 			this.click = function(event) {
# 				event.preventDefault();
#
# 				value = $(event.target).parent().attr('data-value');
#
# 				if (value && this.items[value]) {
# 					this.select(this.items[value]);
# 				}
# 			}
#
# 			// Show
# 			this.show = function() {
# 				var pos = $(this).position();
#
# 				$(this).siblings('ul.dropdown-menu').css({
# 					top: pos.top + $(this).outerHeight(),
#
# 				});
#
# 				$(this).siblings('ul.dropdown-menu').show();
# 			}
#
# 			// Hide
# 			this.hide = function() {
# 				$(this).siblings('ul.dropdown-menu').hide();
# 			}
#
# 			// Request
# 			this.request = function() {
# 				clearTimeout(this.timer);
#
# 				this.timer = setTimeout(function(object) {
# 					object.source($(object).val(), $.proxy(object.response, object));
# 				}, 200, this);
# 			}
#
# 			// Response
# 			this.response = function(json) {
# 				html = '';
#
# 				if (json.length) {
# 					for (i = 0; i < json.length; i++) {
# 						this.items[json[i]['value']] = json[i];
# 					}
#
# 					for (i = 0; i < json.length; i++) {
# 						if (!json[i]['category']) {
# 						html += '<li class="media" data-value="' + json[i]['value'] + '" title="' + json[i]['label'] + '">';
# 						if(json[i]['image'] && json[i]['show_image'] && json[i]['show_image'] == 1 ) {
# 							html += '	<a class="media-left" href="' + json[i]['link'] + '"><img class="pull-left" src="' + json[i]['image'] + '"></a>';
# 						}
#
# 						html += '<div class="media-body">';
# 						html += '<a href="' + json[i]['link'] + '" title="' + json[i]['label'] + '"><span>' +json[i]['cate_name'] + json[i]['label'] + '</span></a>';
# 						if(json[i]['price'] && json[i]['show_price'] && json[i]['show_price'] == 1){
# 							html += '	<div class="price clearfix font-ct">';
# 							if (!json[i]['special']) {
# 								html += '<span class="price-new">'+json[i]['price']+'</span>';;
# 							} else {
# 								html += '<span class="price-new">' + json[i]['special'] + '</span> <span class="price-old" style="text-decoration:line-through;">' + json[i]['price'] + '</span>';
# 							}
# 							if (json[i]['tax']) {
# 								html += '<span class="price-tax hidden">Tax : ' + json[i]['tax'] + '</span>';
# 							}
# 							html += '	</div>';
# 						}
# 						html += '</div></li>';
# 						html += '<li class="clearfix"></li>';
# 						}
# 					}
#
# 					// Get all the ones with a categories
# 					var category = new Array();
#
# 					for (i = 0; i < json.length; i++) {
# 						if (json[i]['category']) {
# 							if (!category[json[i]['category']]) {
# 								category[json[i]['category']] = new Array();
# 								category[json[i]['category']]['name'] = json[i]['category'];
# 								category[json[i]['category']]['item'] = new Array();
# 							}
#
# 							category[json[i]['category']]['item'].push(json[i]);
# 						}
# 					}
#
# 					for (i in category) {
# 						html += '<li class="dropdown-header">' + category[i]['name'] + '</li>';
#
# 						for (j = 0; j < category[i]['item'].length; j++) {
# 							html += '<li data-value="' + category[i]['item'][j]['value'] + '"><a href="#">&nbsp;&nbsp;&nbsp;' + category[i]['item'][j]['label'] + '</a></li>';
# 						}
# 					}
# 				}
#
# 				if (html) {
# 					this.show();
# 				} else {
# 					this.hide();
# 				}
#
# 				$(this).siblings('ul.dropdown-menu').html(html);
# 			}
#
# 			$(this).after('<ul class="dropdown-menu"></ul>');
#
# 		});
# 	}
# })(window.jQuery);
#
# $(document).ready(function() {
# 	var selector = '#search0';
# 	var total = 0;
# 	var showimage = 1;
# 	var showprice = 1;
# 	var character = 10;
# 	var height = 60;
# 	var width = 60;
# 	var oldrequest = null;
#
# 	$(selector).find('input[name=\'search\']').Soautocomplete({
# 		delay: 2000,
# 		source: function(request, response) {
# 			var category_id = $(".select_category select[name=\"category_id\"]").first().val();
# 			if(typeof(category_id) == 'undefined')
# 				category_id = 0;
# 			var limit = 5;
# 			if(request.length >= character && oldrequest != request){
# 			    oldrequest = request;
# 				$.ajax({
# 					url: 'index.php?route=extension/module/so_searchpro/autocomplete&filter_category_id='+category_id+'&limit='+limit+'&width='+width+'&height='+height+'&filter_name='+encodeURIComponent(request),
# 					dataType: 'json',
# 					success: function(json) {
# 						response($.map(json, function(item) {
# 							total = 0;
# 							if(item.total){
# 								total = item.total;
# 							}
#
# 							return {
# 								price:   item.price,
# 								special: item.special,
# 								tax:     item.tax,
# 								label:   item.name,
# 								cate_name:   (item.category_name) ? item.category_name + ' > ' : '',
# 								image:   item.image,
# 								link:    item.link,
# 								minimum:    item.minimum,
# 								show_price:  showprice,
# 								show_image:  showimage,
# 								value:   item.product_id,
# 							}
# 						}));
# 					}
# 				});
# 			}
# 		},
# 	});
# });
#
# </script>
# </div>
# </div>
# </div>
# </div>
# <div class="header-form">
# <div class="button-header current">
# <i class="fa fa-bars"></i>
# </div>
# <div class="dropdown-form toogle_content">
# <span class="text">Menu Link</span>
# <ul id='menu_link' class="dropdown-menu">
# <li class="wishlist"><a href="https://www.topprice.in/index.php?route=account/wishlist" id="wishlist-total" class="top-link-wishlist" title="Wish List (0)"><span>Wish List (0)</span></a></li>
#
# </ul>
# </div>
# <div class="button-user">
# <div class="user-info">
# <a class="link-lg" href="https://www.topprice.in/index.php?route=account/login">Login</a>
# </div>
# </div>
# </div>
#
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
# $().ready(function() {
#     var str1 = window.location.href;
# if(str1.search("route=") == -1) {
#     $.get("index.php?route=common/home/account_refresh2")
#     .done(function(r) {
#         var newDom = $(r);
#         $('#myaccount').replaceWith($('#myaccount',newDom));
#         $('#menu_link').replaceWith($('#menu_link',newDom));
#      });
# }
#
# });
# </script>
# </header> <div id="socialLogin"></div>
# <div class="modal fade in" id="so_sociallogin" tabindex="-1" role="dialog" aria-labelledby="socialLogin" aria-hidden="true">
# <div class="modal-dialog block-popup-login">
# <a href="javascript:void(0)" title="Close" class="close close-login fa fa-times-circle" data-dismiss="modal"></a>
# <div class="tt_popup_login"><strong>Sign in Or Register</strong></div>
# <div class="block-content">
# <div class=" col-reg registered-account">
# <div class="block-content">
# <form class="form form-login" action="https://www.topprice.in/index.php?route=account/login" method="post" id="login-form">
# <fieldset class="fieldset login" data-hasrequired="* Required Fields">
# <div class="field email required email-input">
# <div class="control">
# <input name="email" value="" autocomplete="off" id="email" type="email" class="input-text" title="Email" placeholder="E-mail Address" />
# </div>
# </div>
# <div class="field password required pass-input">
# <div class="control">
# <input name="password" type="password" autocomplete="off" class="input-text" id="pass" title="Password" placeholder="Password" />
# </div>
# </div>
# <div class=" form-group">
# <label class="control-label">Login with your social account</label>
# <div>
# <a href="https://accounts.google.com/o/oauth2/auth?response_type=code&redirect_uri=https%3A%2F%2Fwww.topprice.in%2Findex.php%3Froute%3Dextension%2Fmodule%2Fso_sociallogin%2FGoogleLogin&client_id=736329072463-h71iferg0p5m74nsiigp0qcof55blu7l.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&access_type=offline&approval_prompt=force" class="btn btn-social-icon btn-sm btn-google-plus"><i class="fa fa-google fa-fw" aria-hidden="true"></i></a>
# <a href="https://www.facebook.com/v2.2/dialog/oauth?client_id=482593185447721&state=afcacf6b37d41e48cc1f6f55ebff8619&response_type=code&sdk=php-sdk-5.1.2&redirect_uri=https%3A%2F%2Fwww.topprice.in%2Findex.php%3Froute%3Dextension%2Fmodule%2Fso_sociallogin%2FFacebookLogin&scope=public_profile%2Cemail" class="btn btn-social-icon btn-sm btn-facebook"><i class="fa fa-facebook fa-fw" aria-hidden="true"></i></a>
# </div>
# </div>
# <div class="secondary ft-link-p"><a class="action remind" href=""><span>Forgot Your Password?</span></a></div>
# <div class="actions-toolbar">
# <div class="primary"><button type="submit" class="action login primary" name="send" id="send2"><span>Login</span></button></div>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="col-reg login-customer">
# <h2>NEW HERE?</h2>
# <p class="note-reg">Registration is free and easy!</p>
# <ul class="list-log">
# <li>Save Wish List</li>
# <li>Join <strong>Affiliate Program</strong></li>
# <li>Earn money from <strong>Amazon, Flipkart..</strong></li>
# </ul> <a class="btn-reg-popup" title="Register" href="https://www.topprice.in/index.php?route=account/register">Create an Account</a>
# </div>
# <div style="clear:both;"></div>
# </div>
# </div>
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#                         jQuery(document).ready(function($) {
#                             var $window = $(window);
#                             function checkWidth() {
#                                 var windowsize = $window.width();
#                                 if (windowsize > 767) {
#                                     $('a[href*="account/login"]').click(function (e) {
#                                         e.preventDefault();
#                                         $("#so_sociallogin").modal('show');
#                                     });
#                                 }
#                             }
#                             checkWidth();
#                             $(window).resize(checkWidth);
#                         });
#                     </script>
# <div class="breadcrumbs">
# <div class="container">
# <div class="title-breadcrumb">
# <a href="https://www.topprice.in/"></a>
# <a href="https://www.topprice.in/electronics"></a>
# <a href="https://www.topprice.in/computers-accessories"></a>
# <a href="https://www.topprice.in/computer-accessories-peripherals"></a>
# <a href="https://www.topprice.in/monitors"></a>
# <b>Dell P2719H 27 inch Full HD Monitor</b>
# </div>
# <ul class="breadcrumb-cate">
# <li><a href="https://www.topprice.in/">Home</a></li>
# <li><a href="https://www.topprice.in/electronics">Electronics</a></li>
# <li><a href="https://www.topprice.in/computers-accessories">Computers &amp; Accessories</a></li>
# <li><a href="https://www.topprice.in/computer-accessories-peripherals">Computer Accessories &amp; Peripherals</a></li>
# <li><a href="https://www.topprice.in/monitors">Monitors</a></li>
# <li><a href="https://www.topprice.in/dell-p2719h-27-inch-full-hd-monitor-p134834">Dell P2719H 27 inch Full HD Monitor</a></li>
# </ul>
# </div>
# </div>
# <div class="container product-detail product-full">
# <div class="row">
# <div id="content" class="col-sm-12">
# <div class="sidebar-overlay "></div>
# <div class="product-view product-info clearfix" itemscope itemtype="http://schema.org/Product">
# <div class="product-view-inner clearfix">
# <div class="content-product-left  class-honizol col-md-6 col-sm-12 col-xs-12 ">
# <div class="large-image   ">
# <img itemprop="image" class="product-image-zoom" src="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-600x600.jpg" data-zoom-image="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-600x600.jpg" title="Dell P2719H 27 inch Full HD Monitor" alt="Dell P2719H 27 inch Full HD Monitor" />
# <div class="box-label">
#
#
# <span class="label-product label-sale">
# -70%
# </span>
# </div>
# </div>
# <div id="thumb-slider" class="not_full_slider owl-carousel">
# <a data-index="0" class="img thumbnail" data-image="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-600x600.jpg" title="Dell P2719H 27 inch Full HD Monitor">
# <img src="https://www.topprice.in/image/cache/catalog/datayuge_feed/dd68989525f295d8095a76adb3219ecbd22a0d54-210x210.jpg" title="Dell P2719H 27 inch Full HD Monitor" alt="Dell P2719H 27 inch Full HD Monitor" />
# </a>
# <a data-index="1" class="img thumbnail" data-image="https://www.topprice.in/image/cache/catalog/datayuge_feed/915d5a751d73204d08213810dde57d56e34f1a67-600x600.jpg" title="Dell P2719H 27 inch Full HD Monitor">
# <img src="https://www.topprice.in/image/cache/catalog/datayuge_feed/915d5a751d73204d08213810dde57d56e34f1a67-210x210.jpg" title="Dell P2719H 27 inch Full HD Monitor" alt="Dell P2719H 27 inch Full HD Monitor" />
# </a>
# <a data-index="2" class="img thumbnail" data-image="https://www.topprice.in/image/cache/catalog/datayuge_feed/8a9b6b58e3d60728382e5377e063836521fa3e6f-600x600.jpg" title="Dell P2719H 27 inch Full HD Monitor">
# <img src="https://www.topprice.in/image/cache/catalog/datayuge_feed/8a9b6b58e3d60728382e5377e063836521fa3e6f-210x210.jpg" title="Dell P2719H 27 inch Full HD Monitor" alt="Dell P2719H 27 inch Full HD Monitor" />
# </a>
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
# 								$(function ($) {
# 									var $nav = $("#thumb-slider");
#
# 									$nav.each(function () {
# 										$(this).owlCarousel2({
# 											nav:true,
# 											dots: false,
# 											slideBy: 1,
# 											margin:10,
# 											navText: ['<i class="fa fa-angle-left"></i>','<i class="fa fa-angle-right"></i>'],
# 																						responsive:{
# 												0:{
# 													items:2
# 												},
# 												600:{
# 													items:3
# 												},
# 												1000:{
# 													items:3
# 												}
# 											}
# 										});
# 									})
#
# 								});
# 							</script>
# </div>
# <div class="content-product-right info-right col-md-6 col-sm-12 col-xs-12">
#
#
#  <div class="title-product">
# <meta itemprop="name" content="Dell P2719H 27 inch Full HD Monitor">
# <h1>Dell P2719H 27 inch Full HD Monitor Price in India, Specifications, Reviews & Offers. Buy online @ TATACliq Flipkart Amazon paytmmall.</h1>
# </div>
#
# <div class="box-review" itemprop="review" itemscope itemtype="http://schema.org/Review">
# <div itemprop="reviewRating" itemscope itemtype="http://schema.org/Rating">
# <meta itemprop="ratingValue" content="3" />
# </div>
# <div itemprop="author" itemscope itemtype="http://schema.org/Organization">
# <meta itemprop="name" content="Topprice.in" />
# </div>
# </div>
# <div class="box-review" itemprop="aggregateRating" itemscope itemtype="http://schema.org/AggregateRating">
# <div class="ratings">
# <meta itemprop="worstRating" content="0" />
# <meta itemprop="bestRating" content="5" />
# <meta itemprop="ratingCount" content="1" />
# <div class="rating-box" itemprop="ratingValue" content="3">
# Rating: <span class="fa fa-stack"><i class="fa fa-star-o fa-stack-1x"></i><i class="fa fa-star fa-stack-1x"></i></span>
# <span class="fa fa-stack"><i class="fa fa-star-o fa-stack-1x"></i><i class="fa fa-star fa-stack-1x"></i></span>
# <span class="fa fa-stack"><i class="fa fa-star-o fa-stack-1x"></i><i class="fa fa-star fa-stack-1x"></i></span>
# <span class="fa fa-stack"><i class="fa fa-star-o fa-stack-2x"></i></span>
# <span class="fa fa-stack"><i class="fa fa-star-o fa-stack-2x"></i></span>
# </div>
# </div>
# <a class="write_review_button" href="" onclick="if (!window.__cfRLUnblockHandlers) return false; $('a[href=\'#tab-review\']').trigger('click'); return false;" data-cf-modified-88b0ad11c0af5c1b2c69bc85-="">Write a review</a>
# </div>
# <div class="product-label">
# </div>
# <div class="product-box-desc">
# <div class="inner-box-desc">
# <meta itemprop="brand" content="Dell">
# <div class="brand"><span>Brand:</span><a href="https://www.topprice.in/Dell">Dell</a></div>
# <meta itemprop="gtin8" content="134834">
# <div class="model"><span>Product Code:</span> <span itemprop="sku">134834</span></div>
# <div class="stock"><span> Stock </span> <i class="fa fa-check-square-o"></i> Instock </div>
# </div>
# </div>
# <div class="short_description form-group" itemprop="description">
# Buy <strong>Dell P2719H 27 inch Full HD Monitor</strong> online at TATACliq Flipkart Amazon paytmmall. Dell P2719H 27 inch Full HD Monitor </div>
# <div itemprop="offers" itemscope itemtype="http://schema.org/Offer">
# <meta itemprop="url" content="/dell-p2719h-27-inch-full-hd-monitor-p134834" />
# <span itemprop="offeredBy" itemscope itemtype="http://schema.org/WebSite">
# <meta itemprop="name" content="TATACliq" /></span>
# <meta itemprop='availability' content='http://schema.org/InStock' />
# <meta itemprop="price" content="18399" />
# <meta itemprop="priceCurrency" content="INR" />
# <meta itemprop="priceValidUntil" content="2021-07-30" />
# </div>
# <ul class="list-unstyled">
# <li><span style="text-decoration: line-through;">₹61,578</span></li>
# <li>
# <h2>Best Price: ₹17,999</h2>
# </li>
#  <li>
# <img id="storeimg" src="https://www.topprice.in/image/cache/catalog/Feed%20Logos/TATA_Cliq_Logo-100x50.jpg" alt="TATACliq" title="TATACliq" />
# <a id="LNK_LOWPRICE" class="btn goToStore addToCart" href="https://www.topprice.in/index.php?route=extension/module/price_comparison_store/redirect&amp;url=https%3A%2F%2Fwww.tatacliq.com%2Fdell-p2719h-p-series-68-58-cm-27-inches-monitor-black%2Fp-mp000000004983501%3F&amp;pid=215057&amp;pce_store_id=9" target="_blank" rel="nofollow">GO TO STORE <i class="fa fa-paper-plane" aria-hidden="true"></i></a>
# <button id="BTN_LOWESTPRICE" style="visibility:hidden" onclick="if (!window.__cfRLUnblockHandlers) return false; window.open('https://www.topprice.in/index.php?route=extension/module/price_comparison_store/redirect&amp;url=https%3A%2F%2Fwww.tatacliq.com%2Fdell-p2719h-p-series-68-58-cm-27-inches-monitor-black%2Fp-mp000000004983501%3F&amp;pid=215057&amp;pce_store_id=9')" data-cf-modified-88b0ad11c0af5c1b2c69bc85-="">GO TO STORE</button>
# </li>
# </ul>
#
# <div id="product">
# <div class="box-cart cart clearfix">
#
# <div class="form-group box-info-product">
# <div class="add-to-links wish_comp">
# <ul class="blank">
# <li class="wishlist">
# <a class="icon" data-toggle="tooltip" title="Add to Wish List" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('134834');" data-cf-modified-88b0ad11c0af5c1b2c69bc85-=""><i class="fa fa-heart"></i></a>
# </li>
# <li class="compare">
# <a class="icon" data-toggle="tooltip" title="Compare this Product" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('134834');" data-cf-modified-88b0ad11c0af5c1b2c69bc85-=""><i class="fa fa-random"></i></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="mi-price-comparison-table">
# <table id="price_comparison_table" class="table table-bordered table-hover table-responsive pricetable">
# <caption class="text-center table-bordered" style="height: 35px;"><h2 style="font-size:20px;">Price Comparison</h2></caption>
# <thead>
# <tr>
# <th>STORE</th>
# <th>PRICE</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="mi-img"> <img class="img-responsive" src="https://www.topprice.in/image/cache/catalog/Feed%20Logos/TATA_Cliq_Logo-100x50.jpg" alt="TATACliq" title="TATACliq" />
# </td>
# <td class="mi-price text-center">
# <strong>₹17,999</strong> <span class="small" style="text-decoration: line-through;">₹61,578</span>
# <div><i class="fa fa-truck" aria-hidden="true"></i> FREE Shipping</div>
#
# <div class="hidden-xs"><i class="fa fa-money" aria-hidden="true"></i> COD <i class="fa fa-times-circle text-danger" aria-hidden="true"></i></div>
# </td>
# <td class="text-center">
# <a id="TATACliq" class="btn btn-sm  visible-sm visible-md visible-lg" href="https://www.topprice.in/index.php?route=extension/module/price_comparison_store/redirect&amp;url=https%3A%2F%2Fwww.tatacliq.com%2Fdell-p2719h-p-series-68-58-cm-27-inches-monitor-black%2Fp-mp000000004983501%3F&amp;pid=215057&amp;pce_store_id=9" target="_blank" rel="nofollow">GO TO STORE <i class="fa fa-paper-plane" aria-hidden="true"></i></a>
# ...
# <button type="button" class="btn " data-dismiss="modal" onclick="if (!window.__cfRLUnblockHandlers) return false; model_click()" data-cf-modified-88b0ad11c0af5c1b2c69bc85-="">No</button>
# </div>
# </div>
# </div>
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
# //Kiran
# var StoreName = "";
# var linkid = "";
#
# function model_click() {
#   createCookie(StoreName, StoreName, 1);
#   window.open($(linkid).attr("href"));
# }
#
# $(document).bind('scroll', onScroll);
# function onScroll(){
#       //affvalue1 = getParameterByName('ref');
# 	 //if(affvalue1 == 'ggl'){
# 	  	if(document.getElementById('LNK_LOWPRICE')){
# 		    StoreName = $("#storeimg").attr("alt");
# 		    linkid = "#LNK_LOWPRICE";
# 		if(StoreName != "Amazon"){
# 		//&& StoreName != "Flipkart"){
# 		 if(document.getElementById('Amazon')){
# 		    StoreName = "Amazon";
# 			linkid = "#Amazon";
# 		 }else if(document.getElementById('FlipkartXX')){
# 		    StoreName = "Flipkart";
# 			linkid = "#Flipkart";
# 		 }else{
# 		 	StoreName = "Amazon";
# 			linkid = "#Amazonfind";
# 		 }
# 		}
# 		if(StoreName){
# 			var StoreCookie = getCookie(StoreName);
# 			if (StoreCookie != StoreName) {
# 			   // createCookie(StoreName, StoreName, 1);
#                // window.open($(linkid).attr("href"));
# 			   $('#LowpriceModal').modal('show');
# 			}
# 		}
# 	    }
# 	 //}
# 	 //LowestPriceClick();
# };
#
# jQuery(document).on('ready', function($){
#     document.getElementById("fb-share-button").href="https://www.facebook.com/sharer/sharer.php?u="+escape(window.location.href);
#     document.getElementById("tw-share-button").href="http://www.twitter.com/share?url="+escape(window.location.href);
# });
#
#
#
# $('#review').delegate('.pagination a', 'click', function(e) {
#   e.preventDefault();
#
#     $('#review').fadeOut('slow');
#     $('#review').load(this.href);
#     $('#review').fadeIn('slow');
# });
#
# $('#review').load('index.php?route=product/product/review&product_id=134834');
#
# $('#button-review').on('click', function() {
# 	$.ajax({
# 		url: 'index.php?route=product/product/write&product_id=134834',
# 		type: 'post',
# 		dataType: 'json',
# 		data: 'name=' + encodeURIComponent($('input[name=\'name\']').val()) + '&text=' + encodeURIComponent($('textarea[name=\'text\']').val()) + '&g-recaptcha-response=' + encodeURIComponent(grecaptcha.getResponse()) + '&rating=' + encodeURIComponent($('input[name=\'rating\']:checked').val() ? $('input[name=\'rating\']:checked').val() : ''),
# 		beforeSend: function() {
# 			$('#button-review').button('loading');
# 		},
# 		complete: function() {
# 			$('#button-review').button('reset');
# 		},
# 		success: function(json) {
# 			$('.alert-success, .alert-danger').remove();
#
# 			if (json['error']) {
# 				$('#reviewmsg').append('<div class="alert alert-danger"><i class="fa fa-exclamation-circle"></i> ' + json['error'] + '</div>');
# 				grecaptcha.reset();
# 			}
#
# 			if (json['success']) {
# 				$('#reviewmsg').append('<div class="alert alert-success"><i class="fa fa-check-circle"></i> ' + json['success'] + '</div>');
# 				//document.getElementById("button-review").style.display="none";
# 				grecaptcha.reset();
# 				$('input[name=\'name\']').val('Your Name');
# 				$('textarea[name=\'text\']').val('Your Review');
# 				$('input[name=\'rating\']:checked').prop('checked', false);
# 				$('#review').load('index.php?route=product/product/review&product_id=134834&nosqlcache=x');
# 			}
# 		}
# 	});
# });
#
# //--></script>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript"><!--
# 	$(document).ready(function() {
#
# 		$('.thumb-video2').magnificPopup({
# 			  type: 'iframe',
# 			  iframe: {
# 				patterns: {
# 				   youtube: {
# 					  index: 'youtube.com/',
# 					  id: 'v=', //
# 					  src: '//www.youtube.com/embed/%id%?autoplay=1'
# 						},
# 					}
# 				}
# 			});
#
# 		$('.product-options li.radio').click(function(){
# 			$(this).addClass(function() {
# 				if($(this).hasClass("active")) return "";
# 				return "active";
# 			});
#
# 			$(this).siblings("li").removeClass("active");
# 			$(this).parent().find('.selected-option').html('<span class="label label-success">'+ $(this).find('img').data('original-title') +'</span>');
# 		})
#
# 		// CUSTOM BUTTON
# 		$(".thumb-vertical-outer .next-thumb").click(function () {
# 			$( ".thumb-vertical-outer .lSNext" ).trigger( "click" );
# 		});
#
# 		$(".thumb-vertical-outer .prev-thumb").click(function () {
# 			$( ".thumb-vertical-outer .lSPrev" ).trigger( "click" );
# 		});
#
# 		$(".thumb-vertical-outer .thumb-vertical").lightSlider({
# 			item: 3,
# 			autoWidth: false,
# 			vertical:true,
# 			slideMargin: 10,
# 			verticalHeight:330,
#             pager: false,
# 			controls: true,
#             prevHtml: '<i class="fa fa-angle-up"></i>',
#             nextHtml: '<i class="fa fa-angle-down"></i>',
# 			responsive: [
# 				{
# 					breakpoint: 1199,
# 					settings: {
# 						verticalHeight: 320,
# 						item: 3,
# 					}
# 				},{
# 					breakpoint: 1024,
# 					settings: {
# 						verticalHeight: 235,
# 						item: 2,
# 						slideMargin: 5,
# 					}
# 				},{
# 					breakpoint: 768,
# 					settings: {
# 						verticalHeight: 360,
# 						item: 3,
# 					}
# 				},{
# 					breakpoint: 480,
# 					settings: {
# 						verticalHeight: 110,
# 						item: 1,
# 					}
# 				}
#
# 			]
#
#         });
#
#
# 		$("#thumb-slider .owl2-item").each(function() {
# 			$(this).find("[data-index='0']").addClass('active');
# 		});
#
# 		$('.thumb-video').magnificPopup({
# 		  type: 'iframe',
# 		  iframe: {
# 			patterns: {
# 			   youtube: {
# 				  index: 'youtube.com/', // String that detects type of video (in this case YouTube). Simply via url.indexOf(index).
# 				  id: 'v=', // String that splits URL in a two parts, second part should be %id%
# 				  src: '//www.youtube.com/embed/%id%?autoplay=1' // URL that will be set as a source for iframe.
# 					},
# 				}
# 			}
# 		});
# 	});
#
#
# //--></script>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#
# var ajax_price = function() {
#
# 	$.ajax({
# 		type: 'POST',
# 		url: 'index.php?route=extension/soconfig/liveprice/index',
# 		data: $('.product-info input[type=\'text\'], .product-info input[type=\'hidden\'], .product-info input[type=\'radio\']:checked, .product-info input[type=\'checkbox\']:checked, .product-info select, .product-info textarea'),
# 		dataType: 'json',
# 			success: function(json) {
# 			if (json.success) {
# 				change_price('#price-special', json.new_price.special);
# 				change_price('#price-tax', json.new_price.tax);
# 				change_price('#price-old', json.new_price.price);
# 			}
# 		}
# 	});
# }
#
# var change_price = function(id, new_price) {
# 	$(id).html(new_price);
# }
# $('.product-info input[type=\'text\'], .product-info input[type=\'hidden\'], .product-info input[type=\'radio\'], .product-info input[type=\'checkbox\'], .product-info select, .product-info textarea, .product-info input[name=\'quantity\']').on('change', function() {
# 	ajax_price();
# });
# </script>
# <footer class="footer-container typefooter-2">
# <div class="footer--main">
# <section id="NewsLetterSession" class="section_2 section-color">
# <div class="container page-builder-ltr">
# <div class="row row_34bo row-style ">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 col_9jik col-style">
# <div class="module news-letter">
# <div class="newsletter">
# <div class="title-block">
# <div class="page-heading">
# <i class="fa fa-paper-plane-o" aria-hidden="true"></i> <strong>Sign up to Newsletter</strong> and receive daily deals </div>
# <div class="pre-text">
# AND RECEIVE DAILY DEALS
# </div>
# </div>
# <div class="block_content">
# <form method="post" name="signup" id="signup" class="btn-group form-inline signup">
# <div class="form-group required send-mail">
# <div class="input-box">
# <input type="email" placeholder="Your email address..." value="" class="form-control" id="txtemail" name="txtemail" size="55">
# </div>
# <div class="subcribe">
# <button class="btn btn-default btn-lg" type="submit" onclick="if (!window.__cfRLUnblockHandlers) return false; return subscribe_newsletter();" name="submit" data-cf-modified-88b0ad11c0af5c1b2c69bc85-="">
# <i class="fa fa-envelope hidden"></i><span>Subscribe</span>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#     function subscribe_newsletter()
#     {
#         var emailpattern = /^\w+([\.-]?\w+)*@\w+([\.-]?\w+)*(\.\w{2,3})+$/;
#         var email = $('#txtemail').val();
#         var d = new Date();
#         var createdate = d.getFullYear() + '-' + (d.getMonth()+1) + '-' + d.getDate() + ' ' + d.getHours() + ':' + d.getMinutes() + ':' + d.getSeconds();
#         var status   = 0;
#         var dataString = 'email='+email+'&createdate='+createdate+'&status='+status;
#         if(email != "")
#         {
#             if(!emailpattern.test(email))
#             {
#                 $('.show-error').remove();
#                 $('.send-mail').after('<span class="show-error" style="color: red;margin-left: 10px"> Invalid Email </span>')
#                 return false;
#             }
#             else
#             {
#                 $.ajax({
#                     url: 'index.php?route=extension/module/so_newletter_custom_popup/newsletter',
#                     type: 'post',
#                     data: dataString,
#                     dataType: 'json',
#                     success: function(json) {
#                         $('.show-error').remove();
#                         if(json.message == "Subscription Successfull") {
#                             $('.send-mail').after('<span class="show-error" style="color: #003bb3;margin-left: 10px"> ' + json.message + '</span>');
#                             setTimeout(function () {
#                                 var this_close = $('.popup-close');
#                                 this_close.parent().css('display', 'none');
#                                 this_close.parents().find('.so_newletter_custom_popup_bg').removeClass('popup_bg');
#                             }, 3000);
#
#                         }else{
#                             $('.send-mail').after('<span class="show-error" style="color: red;margin-left: 10px"> ' + json.message + '</span>');
#                         }
#                         var x = document.getElementsByClassName('signup');
#                         for (i = 0; i < x.length; i++) {
#                         x[i].reset();
#                         }
#                     }
#                 });
#                 return false;
#             }
#         }
#         else
#         {
#             alert("Email Is Require");
#             $(email).focus();
#             return false;
#         }
#     }
# </script>
# </div>
# </div>
# </div> </div> </section>
# <section id="footersection" class="section_3 ">
# <div class="container page-builder-ltr">
# <div class="row row_bh6y row-style ">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 col_mehx col-style">
# <div class="row row_q34c border ">
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 col_5j8y col-style">
# <div class="contactinfo"><br><p></p>
# <img src="https://www.topprice.in/image/catalog/Store_Logos/Topprice_logo.png" style="width: 164px;" alt="Topprice">
# <div class="content-footer">
# <ul class="links"> <li> <a href="/index.php?route=information/contact">Contact Us</a> </li> </ul>
# </div>
# </div> </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 col_oz7e col-style">
# <div class="footer-links"><h4 class="title-footer">Information</h4> <ul class="links"> <li> <a href="/reviews">Our Blog / Product Reviews</a> </li><li> <a href="/about-us">About Us</a> </li><li> <a href="/index.php?route=information/contact">Contact Us</a> </li><li> <a href="/Disclaimer">Disclaimer</a> </li><li> <a href="/terms-conditions">Terms & Conditions</a> </li><li> <a href="/affiliate-program">Affiliate program</a> </li></ul></div> </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 col_l99d col-style">
# <div class="footer-links "><h4 class="title-footer">My Account</h4><ul class="links"><li><a href="/index.php?route=account/account">My Account</a></li><li><a href="/index.php?route=account/register">Register</a></li><li><a href="/index.php?route=account/wishlist">Wish List</a></li><li><a href="/index.php?route=account/newsletter">Newsletter</a></li><li><a href="/index.php?route=affiliate/account">Affiliate Account</a></li><li><a href="/index.php?route=affiliate/tracking">Affiliate Tracking</a></li></ul></div> </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 col_lv09 col-style">
# <div class="footer-links ">
# <h4 class="title-footer">Find us on</h4>
# <ul class="list-inline">
# <li><a href="https://www.facebook.com/topprice.in/" target="_blank" rel="noopener"> <i class="fa fa-facebook social-icon"></i></a></li>
# <li><a href="https://twitter.com/topprice9" target="_blank" rel="noopener"> <i class="fa fa-twitter social-icon"></i></a></li>
# <li><a href="https://t.me/s/toppriceindia" target="_blank" rel="noopener"> <i class="fa fa-telegram social-icon"></i></a></li>
# <li><a href="https://www.topprice.in/reviews/r/wg" target="_blank" rel="noopener"> <i class="fa fa-whatsapp social-icon"></i></a></li>
# </ul>
# <br>
# <a href="https://play.google.com/store/apps/details?id=appinventor.ai_kiranreddyduvvuru.Topprice_app" target="_blank" rel="noopener">
# <img src="/image/catalog/TopPrice_Deals/googleplay.png" alt="Topprice.in playstore link" title="Topprice.in playstore link">
# </a>
# </div> </div>
# </div> </div>
# </div> </div> </section>
# </div>
# <div class="footer--bottom ">
# <div class="container">
# <div class="row">
# <div class="col-md-7  col-sm-7 copyright">
# Topprice.in © 2017 - 2021. All Rights Reserved. Designed by <a href="https://www.topprice.in/" target="_blank">Topprice.in</a> </div>
# <div class="col-md-5 col-sm-5 paymen">
# <img src="image/catalog/demo/payment/payments-1.png" alt="imgpayment">
# </div>
# </div>
# </div>
# </div>
# <script async defer src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-59cb7a9285f37d48" type="88b0ad11c0af5c1b2c69bc85-text/javascript"></script>
#
# <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async defer type="88b0ad11c0af5c1b2c69bc85-text/javascript"></script>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#   window.OneSignal = window.OneSignal || [];
#   OneSignal.push(function() {
#     OneSignal.init({
#       appId: "099c2e4d-e569-46ef-a4c1-f30bc3c87349",
#     });
#   });
# </script>
# <script src="https://accounts.google.com/gsi/client" async defer type="88b0ad11c0af5c1b2c69bc85-text/javascript"></script>
# <div id="g_id_onload" data-client_id="736329072463-h71iferg0p5m74nsiigp0qcof55blu7l.apps.googleusercontent.com" data-callback="handleCredentialResponse" data-cancel_on_tap_outside="false" data-auto_select="true" data-skip_prompt_cookie="g1tap">
# </div>
# <script type="88b0ad11c0af5c1b2c69bc85-text/javascript">
#  function handleCredentialResponse(response) {
# 	 $.get( "https://www.topprice.in/index.php?route=extension/module/so_sociallogin/Google1tap&credential=" + response.credential, function( data ) {
# 		 var jsdata = JSON.parse(data);
# 		 if(jsdata.status=='error'){alert("Login failed! Try again..");
# 		 }else{ if (window.location.href.indexOf("route=account") != -1){
#                window.location.assign("https://www.topprice.in/index.php?route=account/account");
#              }}
# 		 //if(jsdata.location){window.location.assign(jsdata.location);}
# 		});
#  }
# </script>
# </footer>
#
# <div class="back-to-top"><i class="fa fa-angle-up"></i></div>
#
#
# <section class="social-widgets visible-lg">
# <ul class="items">
# <li class="item item-01 facebook">
# <a href="catalog/view/theme/so-topdeal/template/social/facebook.php?account=Topprice.in" class="tab-icon"><span class="fa fa-facebook"></span></a>
# <div class="tab-content">
# <div class="title"><h5>FACEBOOK</h5></div>
# <div class="loading">
# <img src="catalog/view/theme/so-topdeal/images/ajax-loader.gif" class="ajaxloader" alt="loader">
# </div>
# </div>
# </li>
# </ul>
# </section>
#
# </div>
# <script src="https://ajax.cloudflare.com/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js" data-cf-settings="88b0ad11c0af5c1b2c69bc85-|49" defer=""></script><script defer src="https://static.cloudflareinsights.com/beacon.min.js" data-cf-beacon='{"rayId":"67432c47f8231829","version":"2021.7.0","r":1,"token":"ad6ab6e3f2b64c0ba058ead233a215dd","si":10}'></script>
# </body>
# </html>

# %%
ama
