# %%
import requests

# %%
# Out:
# {"status":"SUCCESS","date":"Thu, 22 Jul 2021 04:42:08 GMT","httpCode":200,"result":"\n<!DOCTYPE html>\n<html lang=\"en-US\">\n<head>\n\t<meta charset=\"UTF-8\">\n\t<meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no\">\n\t<link rel=\"profile\" href=\"http://gmpg.org/xfn/11\">\n\t<link rel=\"pingback\" href=\"https://yourkoseli.com/xmlrpc.php\">\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src=\"https://www.googletagmanager.com/gtag/js?id=UA-172881507-1\"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag('js', new Date());\n\n  gtag('config', 'UA-172881507-1');\n</script>\n<!-- Facebook Pixel Code -->\n<script>\n!function(f,b,e,v,n,t,s)\n{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\nn.callMethod.apply(n,arguments):n.queue.push(arguments)};\nif(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';\nn.queue=[];t=b.createElement(e);t.async=!0;\nt.src=v;s=b.getElementsByTagName(e)[0];\ns.parentNode.insertBefore(t,s)}(window, document,'script',\n'https://connect.facebook.net/en_US/fbevents.js');\nfbq('init', '163899598927491');\nfbq('track', 'PageView');\n</script>\n<noscript><img height=\"1\" width=\"1\" style=\"display:none\"\nsrc=\"https://www.facebook.com/tr?id=163899598927491&ev=PageView&noscript=1\"\n/></noscript>\n<!-- End Facebook Pixel Code -->\n\t\t\t<script>window.MSInputMethodContext && document.documentMode && document.write('<script src=\"https://yourkoseli.com/wp-content/themes/woodmart/js/libs/ie11CustomProperties.min.js\"><\\/script>');</script>\n\t\t<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v16.7 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop</title>\n\t<meta name=\"description\" content=\"Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur.\" />\n\t<link rel=\"canonical\" href=\"https://yourkoseli.com/\" />\n\t<meta property=\"og:locale\" content=\"en_US\" />\n\t<meta property=\"og:type\" content=\"website\" />\n\t<meta property=\"og:title\" content=\"Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop\" />\n\t<meta property=\"og:description\" content=\"Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur.\" />\n\t<meta property=\"og:url\" content=\"https://yourkoseli.com/\" />\n\t<meta property=\"og:site_name\" content=\"Your Koseli Celebrations\" />\n\t<meta property=\"article:publisher\" content=\"https://www.facebook.com/yourkoselinepal\" />\n\t<meta property=\"article:modified_time\" content=\"2021-07-14T07:09:39+00:00\" />\n\t<meta property=\"og:image\" content=\"https://yourkoseli.com/wp-content/uploads/2021/03/cropped-rect85.png\" />\n\t<meta property=\"og:image:width\" content=\"512\" />\n\t<meta property=\"og:image:height\" content=\"512\" />\n\t<meta name=\"twitter:card\" content=\"summary_large_image\" />\n\t<meta name=\"twitter:site\" content=\"@yourkoselinepal\" />\n\t<meta name=\"twitter:label1\" content=\"Est. reading time\" />\n\t<meta name=\"twitter:data1\" content=\"10 minutes\" />\n\t<script type=\"application/ld+json\" class=\"yoast-schema-graph\">{\"@context\":\"https://schema.org\",\"@graph\":[{\"@type\":\"WebSite\",\"@id\":\"https://yourkoseli.com/#website\",\"url\":\"https://yourkoseli.com/\",\"name\":\"Your Koseli Celebrations\",\"description\":\"Nepal&#039;s First Complete Celebration Portal: Cakes, Gifts and Party Supplies\",\"potentialAction\":[{\"@type\":\"SearchAction\",\"target\":{\"@type\":\"EntryPoint\",\"urlTemplate\":\"https://yourkoseli.com/?s={search_term_string}\"},\"query-input\":\"required name=search_term_string\"}],\"in ...

# %%
print(response.text)
# Out:
# {"status":"SUCCESS","date":"Thu, 22 Jul 2021 04:42:08 GMT","httpCode":200,"result":"\n<!DOCTYPE html>\n<html lang=\"en-US\">\n<head>\n\t<meta charset=\"UTF-8\">\n\t<meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no\">\n\t<link rel=\"profile\" href=\"http://gmpg.org/xfn/11\">\n\t<link rel=\"pingback\" href=\"https://yourkoseli.com/xmlrpc.php\">\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src=\"https://www.googletagmanager.com/gtag/js?id=UA-172881507-1\"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag('js', new Date());\n\n  gtag('config', 'UA-172881507-1');\n</script>\n<!-- Facebook Pixel Code -->\n<script>\n!function(f,b,e,v,n,t,s)\n{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\nn.callMethod.apply(n,arguments):n.queue.push(arguments)};\nif(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';\nn.queue=[];t=b.createElement(e);t.async=!0;\nt.src=v;s=b.getElementsByTagName(e)[0];\ns.parentNode.insertBefore(t,s)}(window, document,'script',\n'https://connect.facebook.net/en_US/fbevents.js');\nfbq('init', '163899598927491');\nfbq('track', 'PageView');\n</script>\n<noscript><img height=\"1\" width=\"1\" style=\"display:none\"\nsrc=\"https://www.facebook.com/tr?id=163899598927491&ev=PageView&noscript=1\"\n/></noscript>\n<!-- End Facebook Pixel Code -->\n\t\t\t<script>window.MSInputMethodContext && document.documentMode && document.write('<script src=\"https://yourkoseli.com/wp-content/themes/woodmart/js/libs/ie11CustomProperties.min.js\"><\\/script>');</script>\n\t\t<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v16.7 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop</title>\n\t<meta name=\"description\" content=\"Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur.\" />\n\t<link rel=\"canonical\" href=\"https://yourkoseli.com/\" />\n\t<meta property=\"og:locale\" content=\"en_US\" />\n\t<meta property=\"og:type\" content=\"website\" />\n\t<meta property=\"og:title\" content=\"Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop\" />\n\t<meta property=\"og:description\" content=\"Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur.\" />\n\t<meta property=\"og:url\" content=\"https://yourkoseli.com/\" />\n\t<meta property=\"og:site_name\" content=\"Your Koseli Celebrations\" />\n\t<meta property=\"article:publisher\" content=\"https://www.facebook.com/yourkoselinepal\" />\n\t<meta property=\"article:modified_time\" content=\"2021-07-14T07:09:39+00:00\" />\n\t<meta property=\"og:image\" content=\"https://yourkoseli.com/wp-content/uploads/2021/03/cropped-rect85.png\" />\n\t<meta property=\"og:image:width\" content=\"512\" />\n\t<meta property=\"og:image:height\" content=\"512\" />\n\t<meta name=\"twitter:card\" content=\"summary_large_image\" />\n\t<meta name=\"twitter:site\" content=\"@yourkoselinepal\" />\n\t<meta name=\"twitter:label1\" content=\"Est. reading time\" />\n\t<meta name=\"twitter:data1\" content=\"10 minutes\" />\n\t<script type=\"application/ld+json\" class=\"yoast-schema-graph\">{\"@context\":\"https://schema.org\",\"@graph\":[{\"@type\":\"WebSite\",\"@id\":\"https://yourkoseli.com/#website\",\"url\":\"https://yourkoseli.com/\",\"name\":\"Your Koseli Celebrations\",\"description\":\"Nepal&#039;s First Complete Celebration Portal: Cakes, Gifts and Party Supplies\",\"potentialAction\":[{\"@type\":\"SearchAction\",\"target\":{\"@type\":\"EntryPoint\",\"urlTemplate\":\"https://yourkoseli.com/?s={search_term_string}\"},\"query-input\":\"required name=search_term_string\"}],\"in ...

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# ### Using ScraperAPI

# %%
import requests

# %%
response = requests.request("GET", "http://api.scraperapi.com?api_key=ae939ef3d321a5638cef3e2178304155&url=http://yourkoseli.com")

# %%
response.text
# Out:
# '\n<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8"><link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin /><script>WebFontConfig={google:{families:["Lato:400,700","Poppins:400,600","Lato:100,100italic,300,300italic,regular,italic,700,700italic,900,900italic"]}};if ( typeof WebFont === "object" && typeof WebFont.load === "function" ) { WebFont.load( WebFontConfig ); }</script><script id="litespeed-webfont-lib" src="https://yourkoseli.com/wp-content/plugins/litespeed-cache/assets/js/webfontloader.min.js" async></script><link data-optimized="2" rel="stylesheet" href="https://yourkoseli.com/wp-content/litespeed/cssjs/dadd5.css?1f632" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://yourkoseli.com/xmlrpc.php">\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-172881507-1"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'UA-172881507-1\');\n</script>\n<!-- Facebook Pixel Code -->\n\n<noscript><img height="1" width="1" style="display:none"\nsrc="https://www.facebook.com/tr?id=163899598927491&ev=PageView&noscript=1"\n/></noscript>\n<!-- End Facebook Pixel Code -->\n\t\t\t<script>window.MSInputMethodContext && document.documentMode && document.write(\'<script src="https://yourkoseli.com/wp-content/themes/woodmart/js/libs/ie11CustomProperties.min.js"><\\/script>\');</script>\n\t\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v16.7 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop</title>\n\t<meta name="description" content="Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur." />\n\t<link rel="canonical" href="https://yourkoseli.com/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="website" />\n\t<meta property="og:title" content="Your Koseli - Order Cakes Online in Kathmandu, Nepal | Cake Delivery Shop" />\n\t<meta property="og:description" content="Order Cakes Online in Nepal or Send Cakes to Nepal Online from Your Koseli Cakes with Sameday Delivery in Kathmandu, Lalitpur, Bhaktapur." />\n\t<meta property="og:url" content="https://yourkoseli.com/" />\n\t<meta property="og:site_name" content="Your Koseli Celebrations" />\n\t<meta property="article:publisher" content="https://www.facebook.com/yourkoselinepal" />\n\t<meta property="article:modified_time" content="2021-07-14T07:09:39+00:00" />\n\t<meta property="og:image" content="https://yourkoseli.com/wp-content/uploads/2021/03/cropped-rect85.png" />\n\t<meta property="og:image:width" content="512" />\n\t<meta property="og:image:height" content="512" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:site" content="@yourkoselinepal" />\n\t<meta name="twitter:label1" content="Est. reading time" />\n\t<meta name="twitter:data1" content="10 minutes" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://yourkoseli.com/#website","url":"https://yourkoseli.com/","name":"Your Koseli Celebrations","description":"Nepal&#039;s First Complete Celebration Portal: Cakes, Gifts and Party Supplies","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://yourkoseli.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://yourkoseli.com/#webpage","url":"h ...

# %% [markdown]
# #### Listing URLS selling Laptop

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd
from requests_html import HTMLSession
import csv

# %%
query = "dell p2719h price in india"

# %%
def get_source(url):
    """Return the source code for the provided URL. 

    Args: 
        url (string): URL of the page to scrape.

    Returns:
        response (object): HTTP response object from requests_html. 
    """
    try:
        session = HTMLSession()
        response = session.get(url)
        return response

    except requests.exceptions.RequestException as e:
        print(e)

def scrape_google(query):
    """ Returns the links of top 10 google searches
    Input: Google Quer you want to make
    """

    query = urllib.parse.quote_plus(query)
    response = get_source("https://www.google.com/search?q=" + query)

    links = list(response.html.absolute_links)
    google_domains = ('https://www.google.', 
                      'https://google.', 
                      'https://webcache.googleusercontent.', 
                      'http://webcache.googleusercontent.', 
                      'https://policies.google.',
                      'https://support.google.',
                      'https://maps.google.',
                      "https://translate.google."
                     )

    for url in links[:]:
        if url.startswith(google_domains):
            links.remove(url)

    return links

# %%
urls = scrape_google(query)

# %%
with open("urls.csv", 'w', newline='') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(urls)
